# %%
def subComplex( z1, z2): 
    return z1-z2 
  
# driver program 
z1 = complex(2, 3) 
z2 = complex(1, 2) 
print( "Subtraction is : ", subComplex(z1, z2))
# Out:
# Subtraction is :  (1+1j)

# %%
f=256 ** (1/4) 
print(f)
# Out:
# 4.0

# %%
x = 5
y = 10
temp = x
x = y
y = temp
print(x)
print(y)
# Out:
# 10
# 5

# %%
x = 5
y = 10
x, y = y, x
print(x)
print(y)
# Out:
# 10
# 5

# %%
F=80
K = (F-32)/1.8+273.15
print(K)

C=(5*(F-32))/9
print(C)
# Out:
# 299.81666666666666
# 26.666666666666668

# %%
print(type(1234))


print(type(55.50))

print(type(6+4j))

print(type("hello"))

print(type([1,2,3,4]))

print(type((1,2,3,4)))

print(type({1:"one", 2:"two", 3:"three"}))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
Steps to create Github profile &
upload Githubs Assignment link as discussed by Dr.Darshan SIr:
    1. Create a GitHub account.
    2. Create a repository in your GitHub account.
    3. Upon completion of assignment, upload the file in your repository.
    4. Copy the URL of the link after uploading the assignment file to the repo.
    5. Fill the Google Form given by Lets Upgrade team & paste the URL & submit.
    6. Verify if you have submitted the URL correctly by clinking on the
    link received to our gmail.
